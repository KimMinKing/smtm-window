# %% [markdown]
# ## 업비트 API 실습

# %%
import os
import jwt  # PyJWT
import uuid
import hashlib
from urllib.parse import urlencode, unquote

import requests

# %% [markdown]
# ### 환경변수 호출

# %%
from dotenv import load_dotenv

load_dotenv()

ACCESS_KEY = os.environ["UPBIT_OPEN_API_ACCESS_KEY"]
SECRET_KEY = os.environ["UPBIT_OPEN_API_SECRET_KEY"]
SERVER_URL = os.environ["UPBIT_OPEN_API_SERVER_URL"]
SERVER_URL
# Out:
# 'http://api.upbit.com'

# %% [markdown]
# os.environ을 조회 해 보았을때 .env에서 추가한 변수들이 정상적으로 추가되어 있는지 확인해보자
# 만약 정상적으로 로딩이 안된다면 아래 명령어로 .env 파일을 로딩해보자
# `%dotenv {.env파일의 절대 또는 상대경로}/.env`

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\fback\\AppData\\Roaming',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': 'true',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_14144_EXRPBCSDZZDISDKO',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'MAGNI',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': 'C:\\ProgramData\\anaconda3\\Scripts\\conda.exe',
#         'CONDA_PREFIX': 'C:\\ProgramData\\anaconda3',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': 'C:\\ProgramData\\anaconda3\\python.exe',
#         'CONDA_ROOT': 'C:\\ProgramData\\anaconda3',
#         'CONDA_SHLVL': '1',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_7776': '1',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\fback',
#         'INTEL_DEV_REDIST': 'C:\\Program Files (x86)\\Common Files\\Intel\\Shared Libraries\\',
#         'JPY_INTERRUPT_EVENT': '1584',
#         'LOCALAPPDATA': 'C:\\Users\\fback\\AppData\\Local',
#         'LOGONSERVER': '\\\\MAGNI',
#         'MIC_LD_LIBRARY_PATH': 'C:\\Program Files (x86)\\Common Files\\Intel\\Shared Libraries\\compiler\\lib\\mic',
#         'NUMBER_OF_PROCESSORS': '12',
#         'ONEDRIVE': 'C:\\Users\\fback\\OneDrive',
#         'ONEDRIVECONSUMER': 'C:\\Users\\fback\\OneDrive',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\ProgramData\\anaconda3;C:\\ProgramData\\anaconda3;C:\\ProgramData\\anaconda3\\Library\\mingw-w64\\bin;C:\\ProgramData\\anaconda3\\Library\\usr\\bin;C:\\ProgramData\\anaconda3\\Library\\bin;C:\\ProgramData\\anaconda3\\Scripts;C:\\ProgramData\\anaconda3\\bin;C:\\ProgramData\\anaconda3\\condabin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\Program Files (x86)\\Common Files\\Intel\\Shared Libraries\\redist\\intel64\\compiler;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Bandizip;C:\\Users\\fback\\Documents\\vscode;C:\\ProgramData\\anaconda3;C:\\Users\\fback\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\fback\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\ProgramData\\anaconda3;C:\\ProgramData\\anaconda3\\Library;C:\\ProgramData\\anaconda3\\Scripts;.',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#         'PROCESSOR_LEVEL': '23',
#         'PROCESSOR_REVISION': '7100',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(base) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHONUTF8': '1',
#         'SESSIONNAME': 'Console',
#         'SSL_CERT_FILE': 'C:\\ProgramData\\anaconda3\\Library\\ssl\\cacert.pem',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\WINDOWS',
#         'TEMP': 'C:\\Users\\fback\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\fback\\AppData\\Local\\Temp',
#         'UPBIT_OPEN_API_ACCESS_KEY': '0ZA4MmePCxxOrZahdxV5AwWYXuYxuflKwkpyxx2x',
#         'UPBIT_OPEN_API_SECRET_KEY': 'IkreLTjnrSxBDdx295Ftl8xUiRIzNvxWRj75zTDm',
#         'UPBIT_OPEN_API_SERVER_URL': 'http://api.upbit.com',
#         'USERDOMAIN': 'MAGNI',
#         'USERDOMAIN_ROAMINGPROFILE': 'MAGNI',
#         'USERNAME': 'fback',
#         'USERPROFILE': 'C:\\Users\\fback',
#         'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\fback\\AppData\\Roaming\\Code\\CachedData\\863d2581ecda6849923a2118d93a088b0745d9d6',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\Users\\fback\\AppData\\Local\\Programs\\Microsoft VS Code',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\a3d125a8-1.87.2-main-sock',
#         'VSCODE_L10N_BUNDLE_LOCATION': 'file:///c%3A/Users/fback/.vscode/extensions/ms-ceintl.vscode-language-pack-ko-1.87.2024031309/translations/extensions/vscode.json-language-features.i18n.json',
#         'VSCODE_NLS_CONFIG': '{"locale":"ko","osLocale":"ko","availableLanguages":{"*":"ko"},"_languagePackId":"d7923a5e9c189bd20f0c04fffd902b65.ko","_translationsConfigFile":"C:\\\\Users\\\\fback\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\d7923a5e9c189bd20f0c04fffd902b65.ko\\\\tcf.json","_cacheRoot":"C:\\\\Users\\\\fback\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\d7923a5e9c189bd20f0c04fffd902b65.ko","_resolvedLanguagePackCoreLocation":"C:\\\\Users\\\\fback\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\d7923a5e9c189bd20f0c04fffd902b65.ko\\\\863d2581ecda6849923a2118d93a088b0745d9d6","_corruptedFile":"C:\\\\Users\\\\fback\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\d7923a5e9c189bd20f0c04fffd902b65.ko\\\\corrupted.info","_languagePackSupport":true}',
#         'VSCODE_PID': '14144',
#         'WINDIR': 'C:\\WINDOWS',
#         '_CONDA_OLD_CHCP': '949',
#         '__CONDA_OPENSLL_CERT_FILE_SET': '"1"',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %% [markdown]
# ### 토큰 만들기

# %%
def create_token(query=None):
    """API에 사용될 토큰을 생성"""
    if query is None:
        print("Start create token without query")
        payload = {
            "access_key": ACCESS_KEY,
            "nonce": str(uuid.uuid4()),
        }

        jwt_token = jwt.encode(payload, SECRET_KEY)
        authorization_token = "Bearer {}".format(jwt_token)
        return authorization_token

    # query는 dict 타입입니다.
    print("Start create token without query")
    print(query)
    m = hashlib.sha512()
    m.update(urlencode(query).encode())
    print("url encoded_query")
    print(urlencode(query).encode())
    query_hash = m.hexdigest()

    print("hash of encoded_query")
    print(query_hash)

    payload = {
        "access_key": ACCESS_KEY,
        "nonce": str(uuid.uuid4()),
        "query_hash": query_hash,
        "query_hash_alg": "SHA512",
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorization_token = "Bearer {}".format(jwt_token)
    return authorization_token

# %% [markdown]
# ### 파라미터 없이 토큰 생성

# %%
create_token()
# Out:
# Start create token without query
# 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJhY2Nlc3Nfa2V5IjoiMFpBNE1tZVBDeHhPclphaGR4VjVBd1dZWHVZeHVmbEt3a3B5eHgyeCIsIm5vbmNlIjoiY2Y5MmRiN2EtZTYxNi00NWJjLWEyYmYtZmJhZTBmNmE5ZTZlIn0.tNaOgo_Oiy_NNExJX3srb4ccZhbM8FzzIyWIYwMeK8g'

# %% [markdown]
# ### 파라미터가 포함된 토큰 생성

# %%
create_token({'market': 'KRW-BTC', 'side': 'bid', 'price': '10000', 'ord_type': 'price'})
# Out:
# Start create token without query
# {'market': 'KRW-BTC', 'side': 'bid', 'price': '10000', 'ord_type': 'price'}
# url encoded_query
# b'market=KRW-BTC&side=bid&price=10000&ord_type=price'
# hash of encoded_query
# 5a62dae6bfcaf9d69ae615ce7ecee097dcf4a2f4fa751a75af5f88905740c2ad8813c153bb383a3337a03aac634efdf950b846aa963448628226c027c793422c
# 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..SufRSbT0NA8-k4qgYkjm1kl2fX2s2GzIm7dfBgxEosU'

# %% [markdown]
# ### 계좌 정보 조회

# %%
def query_account():
    token = create_token()
    headers = {"Authorization": token}

    res = requests.get(SERVER_URL + "/v1/accounts", headers=headers)
    return res.json()

# %%
query_account()
# Out:
# Start create token without query
# [{'currency': 'KRW',
#   'balance': '1154661.37626848',
#   'locked': '0',
#   'avg_buy_price': '0',
#   'avg_buy_price_modified': True,
#   'unit_currency': 'KRW'},
#  {'currency': 'VET',
#   'balance': '76.23250152',
#   'locked': '0',
#   'avg_buy_price': '65.72',
#   'avg_buy_price_modified': False,
#   'unit_currency': 'KRW'},
#  {'currency': 'GRT',
#   'balance': '15',
#   'locked': '0',
#   'avg_buy_price': '499.3',
#   'avg_buy_price_modified': False,
#   'unit_currency': 'KRW'},
#  {'currency': 'APENFT',
#   'balance': '0.00000144',
#   'locked': '0',
#   'avg_buy_price': '0',
#   'avg_buy_price_modified': False,
#   'unit_currency': 'KRW'}]

# %% [markdown]
# ### 주문하기

# %%
def send_order(query):
    query_string = unquote(urlencode(query, doseq=True)).encode("utf-8")
    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }
        
    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorization_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorization_token}

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}
    
    res = requests.post(SERVER_URL + "/v1/orders", json=query, headers=headers)
    res = requests.post('https://api.upbit.com' + '/v1/orders', json=query, headers=headers)

    return res

# %% [markdown]
# ### 시장 가격 매수 주문하기

# %%
query = {
  'market': 'KRW-BTC',
  'side': 'bid',
  'ord_type': 'limit',
  'price': '100.0',
  'volume': '0.01'
}
print(send_order(query))
print(send_order(query).json())
# Out:
# <Response [200]>
# []

# %% [markdown]
# ### 시장 가격 매도 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'ask',
    'volume': '0.0002',
    'ord_type': 'market'
}
send_order(query)
# Out:
# []

# %% [markdown]
# ### 고정 가격 매수 주문하기

# %%
params = {
    'market': 'KRW-BTC',
    'side': 'bid',
    'ord_type': 'limit',
    'price': '1300',
    'volume': '10'}
send_order(params)
# Out:
# <Response [201]>

# %% [markdown]
# ### 고정 가격 매도 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'ask',
    'price': '39760000',
    'volume': '0.0002',
    'ord_type': 'limit'
}
send_order(query)
# Out:
# []

# %% [markdown]
# ### 주문조회

# %%
def query_order_list(is_done_state=False):
    query_states = ["wait", "watch"]
    if is_done_state:
        query_states = ["done", "cancel"]

    states_query_string = '&'.join(["states[]={}".format(state) for state in query_states])
    query_string = states_query_string.encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.get("https://api.upbit.com" + "/v1/orders", params=query_string, headers=headers)

    return res.json()

# %% [markdown]
# ### 대기 중인 주문 조회

# %%
query_order_list()
# Out:
# []

# %% [markdown]
# ### 체결 된 주문 조회

# %%
query_order_list(True)
# Out:
# [{'uuid': '2a6cfeeb-a794-475f-a702-82a6a8da6f0b',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-ANKR',
#   'created_at': '2024-04-01T22:59:26+09:00',
#   'volume': '6411.1842804',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '304.723588847412',
#   'locked': '0',
#   'executed_volume': '6411.1842804',
#   'trades_count': 1},
#  {'uuid': '757244f4-bdb1-4995-a5bf-8577777bd309',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '603613',
#   'state': 'cancel',
#   'market': 'KRW-ANKR',
#   'created_at': '2024-04-01T22:55:25+09:00',
#   'reserved_fee': '301.8065',
#   'remaining_fee': '0.00000000017',
#   'paid_fee': '301.80649999983',
#   'locked': '0.00000034017',
#   'executed_volume': '6411.1842804',
#   'trades_count': 1},
#  {'uuid': '33725aca-1e92-449e-b0af-8539f187bd6d',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '91.45',
#   'state': 'done',
#   'market': 'KRW-ANKR',
#   'created_at': '2024-04-01T22:34:17+09:00',
#   'volume': '6604.13385826',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '301.9740206689385',
#   'locked': '0',
#   'executed_volume': '6604.13385826',
#   'trades_count': 1},
#  {'uuid': '15312e98-6900-46c4-8598-f706668bbdcd',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '603882',
#   'state': 'cancel',
#   'market': 'KRW-ANKR',
#   'created_at': '2024-04-01T22:33:58+09:00',
#   'reserved_fee': '301.941',
#   'remaining_fee': '0.0000000003528',
#   'paid_fee': '301.9409999996472',
#   'locked': '0.0000007059528',
#   'executed_volume': '6604.13385826',
#   'trades_count': 1},
#  {'uuid': '92b5c91b-dd3f-47a7-82e0-2b99328982fb',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '5893',
#   'state': 'done',
#   'market': 'KRW-WAVES',
#   'created_at': '2024-04-01T22:24:18+09:00',
#   'volume': '102.43875995',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '301.835806192675',
#   'locked': '0',
#   'executed_volume': '102.43875995',
#   'trades_count': 1},
#  {'uuid': '531906f5-4626-421e-8856-97dc7300b0ff',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '5906',
#   'state': 'cancel',
#   'market': 'KRW-WAVES',
#   'created_at': '2024-04-01T22:23:52+09:00',
#   'volume': '102.43875995',
#   'remaining_volume': '102.43875995',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '102.43875995',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'de44b4c8-949d-4ff0-93ba-842696f3bd61',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '604696',
#   'state': 'cancel',
#   'market': 'KRW-WAVES',
#   'created_at': '2024-04-01T22:23:30+09:00',
#   'reserved_fee': '302.348',
#   'remaining_fee': '0.000000007575',
#   'paid_fee': '302.347999992425',
#   'locked': '0.000015157575',
#   'executed_volume': '102.43875995',
#   'trades_count': 2},
#  {'uuid': '8826397c-e4e4-41f6-aad8-d8930e7093ca',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-CRO',
#   'created_at': '2024-04-01T22:20:30+09:00',
#   'volume': '2707.53363228',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '303.108390133746',
#   'locked': '0',
#   'executed_volume': '2707.53363228',
#   'trades_count': 1},
#  {'uuid': 'c0e114c0-3756-411d-b064-29895811afbb',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '603780',
#   'state': 'cancel',
#   'market': 'KRW-CRO',
#   'created_at': '2024-04-01T22:19:54+09:00',
#   'reserved_fee': '301.89',
#   'remaining_fee': '0.00000000078',
#   'paid_fee': '301.88999999922',
#   'locked': '0.00000156078',
#   'executed_volume': '2707.53363228',
#   'trades_count': 1},
#  {'uuid': 'a0596735-1319-4c43-b8ed-ab9220456e8a',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '52.37',
#   'state': 'done',
#   'market': 'KRW-ZIL',
#   'created_at': '2024-04-01T21:41:18+09:00',
#   'volume': '11553.03270745',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '302.51616144457825',
#   'locked': '0',
#   'executed_volume': '11553.03270745',
#   'trades_count': 2},
#  {'uuid': '662706b9-6658-43b2-8dda-3e8c44c09402',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '603133',
#   'state': 'cancel',
#   'market': 'KRW-ZIL',
#   'created_at': '2024-04-01T21:40:40+09:00',
#   'reserved_fee': '301.5665',
#   'remaining_fee': '0.000000000119',
#   'paid_fee': '301.566499999881',
#   'locked': '0.000000238119',
#   'executed_volume': '11553.03270745',
#   'trades_count': 2},
#  {'uuid': '4a4cfca2-bcb7-4312-b295-afae05ceb375',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1410',
#   'state': 'done',
#   'market': 'KRW-ID',
#   'created_at': '2024-04-01T21:35:29+09:00',
#   'volume': '428.11923349',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '301.82405961045',
#   'locked': '0',
#   'executed_volume': '428.11923349',
#   'trades_count': 1},
#  {'uuid': '851542ed-c5ad-49f5-9ed1-de5358fa6806',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '603220',
#   'state': 'cancel',
#   'market': 'KRW-ID',
#   'created_at': '2024-04-01T21:34:25+09:00',
#   'reserved_fee': '301.61',
#   'remaining_fee': '0.000000006295',
#   'paid_fee': '301.609999993705',
#   'locked': '0.000012596295',
#   'executed_volume': '428.11923349',
#   'trades_count': 1},
#  {'uuid': '66d0e37c-4d09-41ae-a3f8-72672f8a0f43',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '5010',
#   'state': 'cancel',
#   'market': 'KRW-VET',
#   'created_at': '2024-04-01T00:09:19+09:00',
#   'reserved_fee': '2.505',
#   'remaining_fee': '0.0000000000528',
#   'paid_fee': '2.5049999999472',
#   'locked': '0.0000001056528',
#   'executed_volume': '76.23250152',
#   'trades_count': 1},
#  {'uuid': 'fb3cca45-00e8-4e41-9c37-f7298ced29cb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '65.59',
#   'state': 'cancel',
#   'market': 'KRW-VET',
#   'created_at': '2024-04-01T00:08:55+09:00',
#   'volume': '80',
#   'remaining_volume': '80',
#   'reserved_fee': '2.6236',
#   'remaining_fee': '2.6236',
#   'paid_fee': '0',
#   'locked': '5249.8236',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '2a178393-3242-4995-8e7a-3279abbec4e6',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '65.58',
#   'state': 'cancel',
#   'market': 'KRW-VET',
#   'created_at': '2024-04-01T00:08:06+09:00',
#   'volume': '78',
#   'remaining_volume': '78',
#   'reserved_fee': '2.55762',
#   'remaining_fee': '2.55762',
#   'paid_fee': '0',
#   'locked': '5117.79762',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'c945ceb0-f42b-40dc-a84b-c4033e328ae8',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '66.16',
#   'state': 'done',
#   'market': 'KRW-VET',
#   'created_at': '2024-03-31T23:46:34+09:00',
#   'volume': '18302.15043749',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '605.52664722435665',
#   'locked': '0',
#   'executed_volume': '18302.15043749',
#   'trades_count': 1},
#  {'uuid': '0027984f-ea6c-41f3-aae4-02b3535ea772',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '66.4',
#   'state': 'done',
#   'market': 'KRW-VET',
#   'created_at': '2024-03-31T23:45:47+09:00',
#   'volume': '9134.59974267',
#   'remaining_volume': '0',
#   'reserved_fee': '303.268711456644',
#   'remaining_fee': '0',
#   'paid_fee': '303.268711456644',
#   'locked': '0',
#   'executed_volume': '9134.59974267',
#   'trades_count': 1},
#  {'uuid': 'af77705b-1cdd-4d42-8436-b293fccf790b',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '608150',
#   'state': 'cancel',
#   'market': 'KRW-VET',
#   'created_at': '2024-03-31T23:45:16+09:00',
#   'reserved_fee': '304.075',
#   'remaining_fee': '0.0000000000515',
#   'paid_fee': '304.0749999999485',
#   'locked': '0.0000001030515',
#   'executed_volume': '9167.55069482',
#   'trades_count': 3},
#  {'uuid': '6e20ee37-b623-4e02-9961-fbdebf8bd1d9',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '71.01',
#   'state': 'done',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T23:07:36+09:00',
#   'volume': '8595.80498866',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '305.1940561223733',
#   'locked': '0',
#   'executed_volume': '8595.80498866',
#   'trades_count': 1},
#  {'uuid': 'ea0f4d6b-98db-4b90-b0b2-9ed155baaaca',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '606520',
#   'state': 'cancel',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T23:06:57+09:00',
#   'reserved_fee': '303.26',
#   'remaining_fee': '0.0000000000752',
#   'paid_fee': '303.2599999999248',
#   'locked': '0.0000001504752',
#   'executed_volume': '8595.80498866',
#   'trades_count': 2},
#  {'uuid': '55a30d8d-f056-4c4f-826a-34a02a4cfcdc',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '58.29',
#   'state': 'done',
#   'market': 'KRW-JST',
#   'created_at': '2024-03-31T23:03:26+09:00',
#   'volume': '20820.8540559',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '606.8237914592055',
#   'locked': '0',
#   'executed_volume': '20820.8540559',
#   'trades_count': 2},
#  {'uuid': 'f9a2a7d6-07f4-4845-802d-b1b4bffa5667',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '58.38',
#   'state': 'cancel',
#   'market': 'KRW-JST',
#   'created_at': '2024-03-31T23:03:10+09:00',
#   'volume': '20820.8540559',
#   'remaining_volume': '20820.8540559',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '20820.8540559',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '2b63d54a-6321-4a61-972e-f350f12222c7',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '58.51',
#   'state': 'cancel',
#   'market': 'KRW-JST',
#   'created_at': '2024-03-31T23:02:34+09:00',
#   'volume': '20820.8540559',
#   'remaining_volume': '20820.8540559',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '20820.8540559',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '12fcaaf8-5716-433c-9447-6dbbe1b0ede1',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1214064',
#   'state': 'cancel',
#   'market': 'KRW-JST',
#   'created_at': '2024-03-31T23:02:03+09:00',
#   'reserved_fee': '607.032',
#   'remaining_fee': '0.0000000002355',
#   'paid_fee': '607.0319999997645',
#   'locked': '0.0000004712355',
#   'executed_volume': '20820.8540559',
#   'trades_count': 1},
#  {'uuid': 'a99c0a48-5656-4a06-ae72-3e685dd27137',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1858',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T22:59:14+09:00',
#   'volume': '163.43797093',
#   'remaining_volume': '163.43797093',
#   'reserved_fee': '151.83387499397',
#   'remaining_fee': '151.83387499397',
#   'paid_fee': '0',
#   'locked': '303819.58386293397',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '2167350b-8250-4c0b-8f3d-f0d43d147586',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-CELO',
#   'created_at': '2024-03-31T19:19:39+09:00',
#   'volume': '682.74084434',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '607.6393514626',
#   'locked': '0',
#   'executed_volume': '682.74084434',
#   'trades_count': 1},
#  {'uuid': '0633ed5c-5322-4fe9-bb5a-75de3285c042',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1788',
#   'state': 'done',
#   'market': 'KRW-CELO',
#   'created_at': '2024-03-31T19:12:12+09:00',
#   'volume': '682.74084434',
#   'remaining_volume': '0',
#   'reserved_fee': '610.37031483996',
#   'remaining_fee': '0',
#   'paid_fee': '610.37031483996',
#   'locked': '0',
#   'executed_volume': '682.74084434',
#   'trades_count': 2},
#  {'uuid': '92c44ea4-62d6-4186-9df0-30436662ab99',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1898',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T19:07:37+09:00',
#   'volume': '643.81553911',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '610.98094661539',
#   'locked': '0',
#   'executed_volume': '643.81553911',
#   'trades_count': 1},
#  {'uuid': '10a7d969-3128-4f4e-8efc-2d47ca6d6ea1',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1218099',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T19:06:41+09:00',
#   'reserved_fee': '609.0495',
#   'remaining_fee': '0.00000000194',
#   'paid_fee': '609.04949999806',
#   'locked': '0.00000388194',
#   'executed_volume': '643.81553911',
#   'trades_count': 1},
#  {'uuid': '251a8bdc-2c5c-4453-9764-dd4da5581531',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1769',
#   'state': 'done',
#   'market': 'KRW-CELO',
#   'created_at': '2024-03-31T19:03:52+09:00',
#   'volume': '689.26953567',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '609.658904300115',
#   'locked': '0',
#   'executed_volume': '689.26953567',
#   'trades_count': 1},
#  {'uuid': '71b54ce5-5812-4329-bd06-bf0dd00f5cf9',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1217250',
#   'state': 'cancel',
#   'market': 'KRW-CELO',
#   'created_at': '2024-03-31T19:03:30+09:00',
#   'reserved_fee': '608.625',
#   'remaining_fee': '0.00000000339',
#   'paid_fee': '608.62499999661',
#   'locked': '0.00000678339',
#   'executed_volume': '689.26953567',
#   'trades_count': 1},
#  {'uuid': 'c971d68c-9255-474b-8952-79c3dc1da12d',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '76.79',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:22:45+09:00',
#   'volume': '15866.31908237',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '609.23381210294875',
#   'locked': '0',
#   'executed_volume': '15866.31908237',
#   'trades_count': 3},
#  {'uuid': 'e4cf48cd-8c29-447a-b7e3-4bc37c4c9736',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '76.94',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:22:09+09:00',
#   'volume': '15866.31908237',
#   'remaining_volume': '15866.31908237',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '15866.31908237',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '2cd6a960-2ba1-46a6-8047-923c17f3cb29',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1217264',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:21:35+09:00',
#   'reserved_fee': '608.632',
#   'remaining_fee': '0.0000000002868',
#   'paid_fee': '608.6319999997132',
#   'locked': '0.0000005738868',
#   'executed_volume': '15866.31908237',
#   'trades_count': 1},
#  {'uuid': '2fb9e790-7c6d-4434-becf-3b5cf5b57cbc',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1908',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T18:20:16+09:00',
#   'volume': '638.61760083',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '609.24119119182',
#   'locked': '0',
#   'executed_volume': '638.61760083',
#   'trades_count': 8},
#  {'uuid': '718485d4-d125-4475-ab45-1e98e05937c7',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1914',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T18:19:29+09:00',
#   'volume': '638.61760083',
#   'remaining_volume': '638.61760083',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '638.61760083',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '8b88fb95-7cc0-4208-9041-9d920be9877f',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1219121',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T18:19:09+09:00',
#   'reserved_fee': '609.5605',
#   'remaining_fee': '0.000000007765',
#   'paid_fee': '609.560499992235',
#   'locked': '0.000015537765',
#   'executed_volume': '638.61760083',
#   'trades_count': 1},
#  {'uuid': 'eb8f6519-4fb8-4b14-b765-72203b3136f1',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '76.97',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:14:27+09:00',
#   'volume': '15854.74831344',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '610.1699888427384',
#   'locked': '0',
#   'executed_volume': '15854.74831344',
#   'trades_count': 1},
#  {'uuid': '9b1ccdae-a870-4acd-b380-f20a745c4113',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '77.03',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:13:08+09:00',
#   'volume': '15854.74831344',
#   'remaining_volume': '15854.74831344',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '15854.74831344',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'b291c5fb-2b9a-4f5f-aa30-76f56b4e9403',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1222084',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T18:12:12+09:00',
#   'reserved_fee': '611.042',
#   'remaining_fee': '0.0000000000224',
#   'paid_fee': '611.0419999999776',
#   'locked': '0.0000000448224',
#   'executed_volume': '15854.74831344',
#   'trades_count': 1},
#  {'uuid': 'c92022c7-87a0-4390-86f0-82c77cea0c18',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1556',
#   'state': 'done',
#   'market': 'KRW-ARK',
#   'created_at': '2024-03-31T18:09:54+09:00',
#   'volume': '786.18682021',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '611.65334612338',
#   'locked': '0',
#   'executed_volume': '786.18682021',
#   'trades_count': 1},
#  {'uuid': '88615885-89d7-4b9d-a5f8-faaf76a88b97',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1561',
#   'state': 'cancel',
#   'market': 'KRW-ARK',
#   'created_at': '2024-03-31T18:09:22+09:00',
#   'volume': '786.18682021',
#   'remaining_volume': '786.18682021',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '786.18682021',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'ef542adc-579d-4cf5-9928-d214c834ca91',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1569',
#   'state': 'cancel',
#   'market': 'KRW-ARK',
#   'created_at': '2024-03-31T18:08:53+09:00',
#   'volume': '786.18682021',
#   'remaining_volume': '786.18682021',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '786.18682021',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'ff6be001-7404-40f3-99c3-00d0da0bd752',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1228810',
#   'state': 'cancel',
#   'market': 'KRW-ARK',
#   'created_at': '2024-03-31T18:08:42+09:00',
#   'reserved_fee': '614.405',
#   'remaining_fee': '0.000000005885',
#   'paid_fee': '614.404999994115',
#   'locked': '0.000011775885',
#   'executed_volume': '786.18682021',
#   'trades_count': 1},
#  {'uuid': '2bc8156b-9596-40b7-8f5f-eab9d8d730d0',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '345.4',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T18:04:19+09:00',
#   'volume': '1758.12014946',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '303.627349811742',
#   'locked': '0',
#   'executed_volume': '1758.12014946',
#   'trades_count': 4},
#  {'uuid': '1e81b401-f193-402f-9352-6f61c1797154',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1388',
#   'state': 'done',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T18:02:55+09:00',
#   'volume': '448.6926612',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '311.3927068728',
#   'locked': '0',
#   'executed_volume': '448.6926612',
#   'trades_count': 1},
#  {'uuid': '0e8cf154-c6a1-4f29-a2a1-421931a5e95f',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '620526',
#   'state': 'cancel',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T18:02:10+09:00',
#   'reserved_fee': '310.263',
#   'remaining_fee': '0.000000006515',
#   'paid_fee': '310.262999993485',
#   'locked': '0.000013036515',
#   'executed_volume': '448.6926612',
#   'trades_count': 2},
#  {'uuid': 'a18548e4-00ee-40ea-af6c-4f09205b6397',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '342.2',
#   'state': 'cancel',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:58:00+09:00',
#   'volume': '1758.12014946',
#   'remaining_volume': '1758.12014946',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '1758.12014946',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '9230ee1d-4628-4d20-8aca-8a3a91fe2261',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1894',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:51:04+09:00',
#   'volume': '327.95509772',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '310.57347754084',
#   'locked': '0',
#   'executed_volume': '327.95509772',
#   'trades_count': 1},
#  {'uuid': 'db37249e-87ff-4d9c-b34b-9a69f83c6461',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '620819',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:50:38+09:00',
#   'reserved_fee': '310.4095',
#   'remaining_fee': '0.00000000802',
#   'paid_fee': '310.40949999198',
#   'locked': '0.00001604802',
#   'executed_volume': '327.95509772',
#   'trades_count': 1},
#  {'uuid': 'ce993799-84e4-421b-beff-93196af2b178',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '67280',
#   'state': 'done',
#   'market': 'KRW-BTG',
#   'created_at': '2024-03-31T17:44:04+09:00',
#   'volume': '9.2366216',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '310.719950624',
#   'locked': '0',
#   'executed_volume': '9.2366216',
#   'trades_count': 2},
#  {'uuid': '6ce4bf16-94b5-4f6c-be03-ce1ec41025b7',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '621717',
#   'state': 'cancel',
#   'market': 'KRW-BTG',
#   'created_at': '2024-03-31T17:43:23+09:00',
#   'reserved_fee': '310.8585',
#   'remaining_fee': '0.000000052',
#   'paid_fee': '310.858499948',
#   'locked': '0.000104052',
#   'executed_volume': '9.2366216',
#   'trades_count': 1},
#  {'uuid': 'e0ffa57c-4dd5-473e-b8e0-1e8c00c2586b',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:42:43+09:00',
#   'volume': '326.68683386',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '311.16920925165',
#   'locked': '0',
#   'executed_volume': '326.68683386',
#   'trades_count': 1},
#  {'uuid': '5d05f424-b5ec-42df-8d4a-f3cab574efc0',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '618071',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:42:10+09:00',
#   'reserved_fee': '309.0355',
#   'remaining_fee': '0.000000000925',
#   'paid_fee': '309.035499999075',
#   'locked': '0.000001850925',
#   'executed_volume': '326.68683386',
#   'trades_count': 4},
#  {'uuid': 'd4c45297-aacc-4a88-bb30-e42bbb171eec',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '343.9',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:36:31+09:00',
#   'volume': '1758.12014946',
#   'remaining_volume': '0',
#   'reserved_fee': '302.308759699647',
#   'remaining_fee': '0',
#   'paid_fee': '302.308759699647',
#   'locked': '0',
#   'executed_volume': '1758.12014946',
#   'trades_count': 1},
#  {'uuid': '4d382c81-211e-434e-abac-8b2bb1794109',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '513.9',
#   'state': 'done',
#   'market': 'KRW-ICX',
#   'created_at': '2024-03-31T17:35:23+09:00',
#   'volume': '2381.61643944',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '611.956344114108',
#   'locked': '0',
#   'executed_volume': '2381.61643944',
#   'trades_count': 8},
#  {'uuid': '39a4fdf5-0a70-463b-a80e-1a3c122c51a6',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '513.9',
#   'state': 'cancel',
#   'market': 'KRW-ICX',
#   'created_at': '2024-03-31T17:35:07+09:00',
#   'volume': '2381.61643944',
#   'remaining_volume': '2381.61643944',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '2381.61643944',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '8db8b4cd-aedc-47a8-96f6-c8961b7ff2bb',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1222960',
#   'state': 'cancel',
#   'market': 'KRW-ICX',
#   'created_at': '2024-03-31T17:34:26+09:00',
#   'reserved_fee': '611.48',
#   'remaining_fee': '0.000000001365',
#   'paid_fee': '611.479999998635',
#   'locked': '0.000002731365',
#   'executed_volume': '2381.61643944',
#   'trades_count': 2},
#  {'uuid': 'f1f39684-8062-4d86-b454-6fe172443c0e',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-ZRX',
#   'created_at': '2024-03-31T17:33:06+09:00',
#   'volume': '1141.96168224',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '612.09146168064',
#   'locked': '0',
#   'executed_volume': '1141.96168224',
#   'trades_count': 1},
#  {'uuid': '0462c730-4944-4b42-9c42-8f60922c6b51',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1077',
#   'state': 'cancel',
#   'market': 'KRW-ZRX',
#   'created_at': '2024-03-31T17:32:41+09:00',
#   'volume': '1141.96168224',
#   'remaining_volume': '1141.96168224',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '1141.96168224',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '41dffc02-a137-4c9a-b7fd-0017679e7a38',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1221899',
#   'state': 'cancel',
#   'market': 'KRW-ZRX',
#   'created_at': '2024-03-31T17:32:09+09:00',
#   'reserved_fee': '610.9495',
#   'remaining_fee': '0.0000000016',
#   'paid_fee': '610.9494999984',
#   'locked': '0.0000032016',
#   'executed_volume': '1141.96168224',
#   'trades_count': 1},
#  {'uuid': '9d75ed28-0671-40ab-9561-776d32a2886c',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:30:24+09:00',
#   'volume': '1538.53751324',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '267.32089292545',
#   'locked': '0',
#   'executed_volume': '1538.53751324',
#   'trades_count': 1},
#  {'uuid': '3280124c-e393-4c0e-981e-f6a84e1da696',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1892',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:28:26+09:00',
#   'volume': '273.4031746',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '258.6394031716',
#   'locked': '0',
#   'executed_volume': '273.4031746',
#   'trades_count': 1},
#  {'uuid': 'a47014e2-6ef0-4173-a8dc-d7ee1f0dbf36',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1906',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:27:46+09:00',
#   'volume': '273.4031746',
#   'remaining_volume': '273.4031746',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '273.4031746',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '9d44b3c0-a59a-4d12-8858-1c29d5a2805b',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '516732',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T17:27:10+09:00',
#   'reserved_fee': '258.366',
#   'remaining_fee': '0.000000003',
#   'paid_fee': '258.365999997',
#   'locked': '0.000006003',
#   'executed_volume': '273.4031746',
#   'trades_count': 1},
#  {'uuid': '92bf6b2a-4d3f-43c4-b4f4-0361e3c9a5a2',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1373',
#   'state': 'cancel',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T17:24:07+09:00',
#   'volume': '124.56661839',
#   'remaining_volume': '124.56661839',
#   'reserved_fee': '85.514983524735',
#   'remaining_fee': '85.514983524735',
#   'paid_fee': '0',
#   'locked': '171115.482032994735',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'fbe22114-b691-4dbf-9338-57af4b85ad23',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '861.9',
#   'state': 'done',
#   'market': 'KRW-GLM',
#   'created_at': '2024-03-31T17:23:20+09:00',
#   'volume': '798.75905585',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '344.2252151185575',
#   'locked': '0',
#   'executed_volume': '798.75905585',
#   'trades_count': 5},
#  {'uuid': '21526fac-a1b0-4c6e-b04f-e177b70d4766',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '683578',
#   'state': 'cancel',
#   'market': 'KRW-GLM',
#   'created_at': '2024-03-31T17:22:33+09:00',
#   'reserved_fee': '341.789',
#   'remaining_fee': '0.000000001785',
#   'paid_fee': '341.788999998215',
#   'locked': '0.000003571785',
#   'executed_volume': '798.75905585',
#   'trades_count': 1},
#  {'uuid': 'd5c72561-196a-406b-a0f8-8529ab4823be',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '345.5',
#   'state': 'cancel',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:19:44+09:00',
#   'volume': '494.87698986',
#   'remaining_volume': '494.87698986',
#   'reserved_fee': '85.489999998315',
#   'remaining_fee': '85.489999998315',
#   'paid_fee': '0',
#   'locked': '171065.489996628315',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '034a9b62-9857-459a-9f01-4bb6cd7149ce',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '345.3',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:18:13+09:00',
#   'volume': '660.32797567',
#   'remaining_volume': '0',
#   'reserved_fee': '114.0056249994255',
#   'remaining_fee': '0',
#   'paid_fee': '114.0056249994255',
#   'locked': '0',
#   'executed_volume': '660.32797567',
#   'trades_count': 1},
#  {'uuid': '291e5c56-cbd5-4122-af4c-d2b5fab725eb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '345.3',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:18:10+09:00',
#   'volume': '878.20953757',
#   'remaining_volume': '0',
#   'reserved_fee': '151.6228766614605',
#   'remaining_fee': '0',
#   'paid_fee': '151.6228766614605',
#   'locked': '0',
#   'executed_volume': '878.20953757',
#   'trades_count': 1},
#  {'uuid': '95973bdf-5dda-4525-821e-ff86b0693ede',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T17:16:49+09:00',
#   'volume': '879.92068732',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '608.02519493812',
#   'locked': '0',
#   'executed_volume': '879.92068732',
#   'trades_count': 1},
#  {'uuid': 'f7ffe08c-82d7-4acc-9cc1-ad9a6f862b59',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1385',
#   'state': 'cancel',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T17:16:11+09:00',
#   'volume': '879.92068732',
#   'remaining_volume': '879.92068732',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '879.92068732',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '70319a98-111c-4d7e-b298-bc2b8f7d53cb',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1213529',
#   'state': 'cancel',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T17:15:14+09:00',
#   'reserved_fee': '606.7645',
#   'remaining_fee': '0.00000000678',
#   'paid_fee': '606.76449999322',
#   'locked': '0.00001356678',
#   'executed_volume': '879.92068732',
#   'trades_count': 3},
#  {'uuid': 'c08e1493-8347-467e-9e00-c64f4c187fb0',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:08:01+09:00',
#   'volume': '3478.64469914',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '607.371364469844',
#   'locked': '0',
#   'executed_volume': '3478.64469914',
#   'trades_count': 1},
#  {'uuid': '8c3f05ac-670e-4894-aa1c-2d05feb726cf',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1214047',
#   'state': 'cancel',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T17:07:18+09:00',
#   'reserved_fee': '607.0235',
#   'remaining_fee': '0.00000000007',
#   'paid_fee': '607.02349999993',
#   'locked': '0.00000014007',
#   'executed_volume': '3478.64469914',
#   'trades_count': 1},
#  {'uuid': '34e93352-7dc5-4097-b2e6-c9593fbc0d8f',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1383',
#   'state': 'done',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T16:40:12+09:00',
#   'volume': '878.71428571',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '607.630928568465',
#   'locked': '0',
#   'executed_volume': '878.71428571',
#   'trades_count': 1},
#  {'uuid': 'a66a1521-28f0-48d9-83a6-89e05d939522',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1211747',
#   'state': 'cancel',
#   'market': 'KRW-PYTH',
#   'created_at': '2024-03-31T16:39:28+09:00',
#   'reserved_fee': '605.8735',
#   'remaining_fee': '0.000000002955',
#   'paid_fee': '605.873499997045',
#   'locked': '0.000005912955',
#   'executed_volume': '878.71428571',
#   'trades_count': 2},
#  {'uuid': 'a8e264f7-8934-4801-8483-707811fdf961',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '338.3',
#   'state': 'cancel',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T16:34:10+09:00',
#   'volume': '1791.83121489',
#   'remaining_volume': '1791.83121489',
#   'reserved_fee': '303.0882499986435',
#   'remaining_fee': '303.0882499986435',
#   'paid_fee': '0',
#   'locked': '606479.5882472856435',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '1f6813c0-0578-415b-acec-450f4d1dcec3',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '69.02',
#   'state': 'done',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T15:43:49+09:00',
#   'volume': '17574.02770384',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '606.4796960595184',
#   'locked': '0',
#   'executed_volume': '17574.02770384',
#   'trades_count': 1},
#  {'uuid': '32124ad4-3d71-4171-a39b-62913ecb46a0',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1210127',
#   'state': 'cancel',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T15:43:28+09:00',
#   'reserved_fee': '605.0635',
#   'remaining_fee': '0.0000000002157',
#   'paid_fee': '605.0634999997843',
#   'locked': '0.0000004316157',
#   'executed_volume': '17574.02770384',
#   'trades_count': 2},
#  {'uuid': 'eb53cb02-8853-4dc5-bee8-eb33ffad52b8',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T15:32:51+09:00',
#   'volume': '17629.22354322',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '605.66895127798015',
#   'locked': '0',
#   'executed_volume': '17629.22354322',
#   'trades_count': 2},
#  {'uuid': '2e1608cf-5d6d-4531-afb6-4dbd670048c3',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1201079',
#   'state': 'cancel',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T15:31:38+09:00',
#   'reserved_fee': '600.5395',
#   'remaining_fee': '0.0000000002107',
#   'paid_fee': '600.5394999997893',
#   'locked': '0.0000004216107',
#   'executed_volume': '17629.22354322',
#   'trades_count': 1},
#  {'uuid': 'ed93054e-19fb-43d2-b2f6-fb8f673f5127',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '67.98',
#   'state': 'cancel',
#   'market': 'KRW-ORBS',
#   'created_at': '2024-03-31T15:31:15+09:00',
#   'volume': '17668.11504515',
#   'remaining_volume': '17668.11504515',
#   'reserved_fee': '600.5392303846485',
#   'remaining_fee': '600.5392303846485',
#   'paid_fee': '0',
#   'locked': '1201678.9999996816485',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '6b515780-3bd1-47f8-b744-6d6647ad2434',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T14:59:16+09:00',
#   'volume': '3555.99053814',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '601.140200472567',
#   'locked': '0',
#   'executed_volume': '3555.99053814',
#   'trades_count': 1},
#  {'uuid': 'bab85079-5dfc-4b38-9dd9-95855a904e16',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1202636',
#   'state': 'cancel',
#   'market': 'KRW-CVC',
#   'created_at': '2024-03-31T14:58:30+09:00',
#   'reserved_fee': '601.318',
#   'remaining_fee': '0.000000000526',
#   'paid_fee': '601.317999999474',
#   'locked': '0.000001052526',
#   'executed_volume': '3555.99053814',
#   'trades_count': 1},
#  {'uuid': 'a4bcb8c5-ec76-46d9-bc48-fbcba3005189',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-GLM',
#   'created_at': '2024-03-31T14:57:03+09:00',
#   'volume': '1395.59388747',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '601.919643665811',
#   'locked': '0',
#   'executed_volume': '1395.59388747',
#   'trades_count': 1},
#  {'uuid': 'e4ca0d33-7f4b-4741-8097-07a7b46199ff',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1205514',
#   'state': 'cancel',
#   'market': 'KRW-GLM',
#   'created_at': '2024-03-31T14:56:48+09:00',
#   'reserved_fee': '602.757',
#   'remaining_fee': '0.000000001707',
#   'paid_fee': '602.756999998293',
#   'locked': '0.000003415707',
#   'executed_volume': '1395.59388747',
#   'trades_count': 1},
#  {'uuid': '43b97d72-cda4-458d-9274-355ca453bb7f',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T14:56:43+09:00',
#   'volume': '15683.91517972',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '603.3602169638284',
#   'locked': '0',
#   'executed_volume': '15683.91517972',
#   'trades_count': 3},
#  {'uuid': '824384d7-cecc-45bf-ae25-9419e6a07877',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1212994',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T14:55:26+09:00',
#   'reserved_fee': '606.497',
#   'remaining_fee': '0.0000000002276',
#   'paid_fee': '606.4969999997724',
#   'locked': '0.0000004554276',
#   'executed_volume': '15683.91517972',
#   'trades_count': 1},
#  {'uuid': 'a616d52c-feae-4c8f-841c-0f7f17723cf3',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T13:19:02+09:00',
#   'volume': '15899.14338429',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '607.1034903903552',
#   'locked': '0',
#   'executed_volume': '15899.14338429',
#   'trades_count': 2},
#  {'uuid': 'c7825804-332e-4937-8739-60b986fd48b5',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1206427',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T13:17:55+09:00',
#   'reserved_fee': '603.2135',
#   'remaining_fee': '0.0000000000374',
#   'paid_fee': '603.2134999999626',
#   'locked': '0.0000000748374',
#   'executed_volume': '15899.14338429',
#   'trades_count': 2},
#  {'uuid': 'b273ee92-d539-4736-8cd8-4ca41f5a32d2',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T12:46:39+09:00',
#   'volume': '639.29835718',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '603.81729835651',
#   'locked': '0',
#   'executed_volume': '639.29835718',
#   'trades_count': 1},
#  {'uuid': '1a944806-fd19-414d-8456-06fd16988334',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1206356',
#   'state': 'cancel',
#   'market': 'KRW-MNT',
#   'created_at': '2024-03-31T12:45:43+09:00',
#   'reserved_fee': '603.178',
#   'remaining_fee': '0.00000000067',
#   'paid_fee': '603.17799999933',
#   'locked': '0.00000134067',
#   'executed_volume': '639.29835718',
#   'trades_count': 1},
#  {'uuid': '0f7b47d6-bed8-45fe-a18f-7b5d69258f4e',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '76.89',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T12:26:29+09:00',
#   'volume': '1566.49630302',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '60.2239503696039',
#   'locked': '0',
#   'executed_volume': '1566.49630302',
#   'trades_count': 1},
#  {'uuid': '21a0bda8-743f-4638-b1fb-61b273196925',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '77.23',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T12:22:12+09:00',
#   'volume': '1566.49630302',
#   'remaining_volume': '0',
#   'reserved_fee': '60.4902547411173',
#   'remaining_fee': '0',
#   'paid_fee': '60.4902547411173',
#   'locked': '0',
#   'executed_volume': '1566.49630302',
#   'trades_count': 1},
#  {'uuid': 'dcf35d64-42d2-4edb-ab59-3d2585f20ec8',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '72.75',
#   'state': 'done',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T11:23:36+09:00',
#   'volume': '16607.7907777',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '604.1083895388375',
#   'locked': '0',
#   'executed_volume': '16607.7907777',
#   'trades_count': 1},
#  {'uuid': '0c473392-6bab-4d86-8719-202fd69b5d30',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '1206556',
#   'state': 'cancel',
#   'market': 'KRW-T',
#   'created_at': '2024-03-31T11:23:14+09:00',
#   'reserved_fee': '603.278',
#   'remaining_fee': '0.0000000000475',
#   'paid_fee': '603.2779999999525',
#   'locked': '0.0000000950475',
#   'executed_volume': '16607.7907777',
#   'trades_count': 1},
#  {'uuid': '1c9fb580-c864-4ea1-a8ed-8eb92246a246',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '0.002303',
#   'state': 'done',
#   'market': 'KRW-BTT',
#   'created_at': '2024-03-31T11:18:28+09:00',
#   'volume': '197820077.7615868',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '227.7898195424672002',
#   'locked': '0',
#   'executed_volume': '197820077.7615868',
#   'trades_count': 1}]

# %% [markdown]
# ### 주문 취소하기

# %%
def cancel_order(order_uuid=None):
    if order_uuid is None:
        return

    query = {
        'uuid': order_uuid,
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.delete(SERVER_URL + "/v1/order", params=query, headers=headers)

    return res.json()

# %% [markdown]
# ### UUID로 주문 최소

# %%
cancel_order('657c9b11-8d63-4db9-b8b9-14094b7992a2')
# Out:
# {'error': {'name': 'order_not_found', 'message': '주문을 찾지 못했습니다.'}}

# %% [markdown]
# ### 최근 거래 내역 조회

# %%
def query_latest_trade(market):
    """최근 거래 내역 조회
    response:
        trade_date_utc: 체결 일자(UTC 기준), String
        trade_time_utc: 체결 시각(UTC 기준), String
        timestamp: 체결 타임스탬프, Long
        trade_price: 체결 가격, Double
        trade_volume: 체결량, Double
        prev_closing_price: 전일 종가, Double
        change_price: 변화량, Double
        ask_bid: 매도/매수, String
        sequential_id: 체결 번호(Unique), Long
    """
    querystring = {
        "market": market,
        "count":"2"
    }

    response = requests.request("GET", SERVER_URL + "/v1/trades/ticks", params=querystring)

    return response.json()
query_latest_trade('KRW-BTC')
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date_utc': '2024-04-01',
#   'trade_time_utc': '15:11:15',
#   'timestamp': 1711984275439,
#   'trade_price': 99193000.0,
#   'trade_volume': 0.00010081,
#   'prev_closing_price': 100970000.0,
#   'change_price': -1777000.0,
#   'ask_bid': 'BID',
#   'sequential_id': 17119842754390000},
#  {'market': 'KRW-BTC',
#   'trade_date_utc': '2024-04-01',
#   'trade_time_utc': '15:11:14',
#   'timestamp': 1711984274969,
#   'trade_price': 99101000.0,
#   'trade_volume': 2.705e-05,
#   'prev_closing_price': 100970000.0,
#   'change_price': -1869000.0,
#   'ask_bid': 'ASK',
#   'sequential_id': 17119842749690003}]
